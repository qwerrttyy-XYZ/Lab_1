# %% [markdown]
# # **Лабораторная работа №1**

# %% [markdown]
# **Тема:** Основы Git и Github

# %% [markdown]
# **Цель работы:** изучение основ Git и Github

# %% [markdown]
# **Ход работы:**\
# Задание 1: Работа с локальным репозиторием посредством командной строки.

# %% [markdown]
# Создание локального репозитория и добавления в него файла.

# %% [markdown]
# ![image.png](attachment:02bf714c-2dd1-4588-9895-9d3cf2ee69c0.png)\
# ![image.png](attachment:4c924468-ddd1-415a-b6d5-6be1fcb5895f.png)\
# ![image.png](attachment:f99c295b-a715-413f-8d44-759a7ae2a5d3.png)\
# ![image.png](attachment:663e3553-869d-4c9c-832b-a395b28624a6.png)

# %% [markdown]
# Процесс сохранения изменений в Git, добавление новой ветви проекта и переход в нее:

# %% [markdown]
# ![image.png](attachment:274fb5b3-e98a-4ff3-a3a7-40d994411583.png)

# %% [markdown]
# Процесс отмены изменений, добавление нового файла и слияния веток master и testrepo

# %% [markdown]
# ![image.png](attachment:be8a7825-3b1b-4183-a2f9-c2154ede46ac.png)\
# ![image.png](attachment:1fcab9dc-081b-4196-9bf5-1528bc369568.png)

# %% [markdown]
# # Выполнение задания 2

# %% [markdown]
# Внешний вид репозитория, созданного через форк чужого репозитория

# %% [markdown]
# ![image.png](attachment:8b2b85ee-3927-48f9-826e-cbc0e222b701.png)

# %% [markdown]
# Процесс клонирования проекта на локальный репозиторий, добавление нового файла и добавление и фиксирование нового файла

# %% [markdown]
# ![image.png](attachment:7cdbcd02-9821-4cb8-aa17-2a071a04ece1.png)

# %% [markdown]
# Внешний вид окна подтверждения слияния проекта от другого человека

# %% [markdown]
# ![image.png](attachment:c1955bb5-828f-4314-924b-ccdaf19d80a0.png)

# %% [markdown]
# # Добавление SSH ключа

# %% [markdown]
# ![image.png](attachment:140eda44-7893-4d17-9c04-ed9af1eb76a9.png)

# %% [markdown]
# # Вывод

# %% [markdown]
# В ходе выполнения лабораторной работы были получены навыки работы с Git и платформой GitHub. Во время выполнения лабораторной работы была обнаружена ошибка при клонировании репозитория на локальную машину из-за отсутствия ssh ключа. Решена путем ввода команды ssh-keygen -t rsa и добавлением ключа в настройках профиля GitHub.

# %% [markdown]
# Выполнил:\
# Бандюков В.Ю.
#
# Проверил:\
# Шайхутдинов Д.В.
